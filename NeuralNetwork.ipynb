# %% [markdown]
# <a href="https://colab.research.google.com/github/SatishPatlolla/SampleRepo/blob/master/NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello "+ "world")
x ,v= 101,102        # integer
y = 3.145      # float
name = "Satish_"  # string
is_active = False  # boolean
print(x,v)
print(y)
print(name)
print(is_active)
# Out:
# hello world
# 101 102
# 3.145
# Satish_
# False

# %%
x=5

if x > 5 :
  print("x is greater than 5")
elif x == 5:
  print("x is equal to 5")
else:
  print("x is less than 5")


for input in range(1,10):
  print(input)

a, b = 10, 3
print(a + b, a - b, a * b, a / b, a % b)

# Comparison
print(a > b, a == b)

# Logical
print(a > 5 and b < 5)
# Out:
# x is equal to 5
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 13 7 30 3.3333333333333335 1
# True False
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-11397788.py in <cell line: 0>()
#      21 print(a > 5 and b < 5)
#      22
# ---> 23 name = input("Enter your name: ")
#      24 age = int(input("Enter your age: "))
#      25 print(f"Hello {name}, you are {age} years old")
#
# TypeError: 'int' object is not callable

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print("Hello {name}, you are {age} years old")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2019099352.py in <cell line: 0>()
# ----> 1 name = input("Enter your name: ")
#       2 age = int(input("Enter your age: "))
#       3 print("Hello {name}, you are {age} years old")
#
# TypeError: 'int' object is not callable

# %%
# For each neuron
#for neurolf_weights, neuron_bias in zip(weights, biases):
#What kind of loop is this and what is zip

a = [1, 2, 3]
b = [10, 20, 30]

for x, y in zip(a, b):
    print(x, y)
# Out:
# 1 10
# 2 20
# 3 30

# %%
# Creating an iterator
class Counter:
    def __init__(self, start, end):
        self.current = start
        self.end = end

    def __iter__(self):
        return self

    def __next__(self):
        if self.current > self.end:
            raise StopIteration
        self.current += 1
        return self.current - 1

for num in Counter(1, 5):
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Basic class
class Dog:
    # Class variable
    species = "Canis familiaris"

    # Constructor
    def __init__(self, name, age):
        # Instance variables
        self.name = name
        self.age = age

    # Instance method
    def bark(self):
        return f"{self.name} says Woof!"

    # String representation
    def __str__(self):
        return f"{self.name} is {self.age} years old"

# Creating objects
dog1 = Dog("Buddy", 3)
dog2 = Dog("Max", 5)

print(dog1.bark())
print(dog2)


# Parent class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        pass

# Child classes
class Dog(Animal):
    def speak(self):
        return f"{self.name} says Woof!"

class Cat(Animal):
    def speak(self):
        return f"{self.name} says Meow!"

# Using inheritance
dog = Dog("Buddy")
cat = Cat("Whiskers")

print(dog.speak())
print(cat.speak())
# Out:
# Buddy says Woof!
# Max is 5 years old
# Buddy says Woof!
# Whiskers says Meow!

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # Private variable

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            return True
        return False

    def get_balance(self):
        return self.__balance

account = BankAccount(1000)
account.deposit(500)
print(account.get_balance())
# Out:
# 1500

# %%
# Basic try-except
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")

# Multiple exceptions
try:
    number = int("abc")
except ValueError:
    print("Invalid number")
except Exception as e:
    print(f"Error: {e}")

# Try-except-else-finally
try:
    file = open("data.txt", "r")
    content = file.read()
except FileNotFoundError:
    print("File not found")
else:
    print("File read successfully")
finally:
    print("Cleanup code runs always")

# Raising exceptions
def divide(a, b):
    if b == 0:
        raise ValueError("Divisor cannot be zero")
    return a / b
# Out:
# Cannot divide by zero!
# Invalid number
# File not found
# Cleanup code runs always

# %%
# Importing modules
import math
print(math.sqrt(16))

# Import specific functions
from math import sqrt, pi
print(sqrt(16))

# Import with alias
import numpy as np

# Create your own module (save as mymodule.py)
# mymodule.py
def greet(name):
    return f"Hello, {name}"
# Out:
# 4.0
# 4.0

# %%
# In another file
import mymodule
print(mymodule.greet("Alice"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-500899701.py in <cell line: 0>()
#       1 # In another file
# ----> 2 import mymodule
#       3 print(mymodule.greet("Alice"))
#
# ModuleNotFoundError: No module named 'mymodule'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import json

# Python to JSON
data = {
    "name": "Alice",
    "age": 30,
    "city": "NYC"
}

json_string = json.dumps(data, indent=3)
print(json_string)

# JSON to Python
json_data = '{"name": "Bob", "age": 25}'
person = json.loads(json_data)
print(person["name"])

# File operations
with open("data.json", "w") as file:
    json.dump(data, file, indent=2)

with open("data.json", "r") as file:
    loaded_data = json.load(file)
# Out:
# {
#    "name": "Alice",
#    "age": 30,
#    "city": "NYC"
# }
# Bob

# %%
from typing import List, Dict, Tuple, Optional, Union, Callable

# Basic type hints
def greet(name: str) -> str:
    return f"Hello, {name}!"

# Collections
def sum_list(numbers: List[int]) -> int:
    return sum(numbers)

def get_user(user_id: int) -> Dict[str, str]:
    return {"name": "Alice", "email": "alice@example.com"}

# Optional (can be None)
def find_user(user_id: int) -> Optional[Dict[str, str]]:
    return None

# Union (multiple types)
def process(value: Union[int, str]) -> str:
    return str(value)

# Callable
def apply_function(func: Callable[[int, int], int], x: int, y: int) -> int:
    return func(x, y)

# Generic types
from typing import TypeVar, Generic

T = TypeVar('T')

class Stack(Generic[T]):
    def __init__(self):
        self.items: List[T] = []

    def push(self, item: T) -> None:
        self.items.append(item)

    def pop(self) -> T:
        return self.items.pop()

# %%
from dataclasses import dataclass, field
from typing import List

# Basic dataclass
@dataclass
class Person:
    name: str
    age: int
    email: str = "unknown@example.com"  # Default value

    def greet(self):
        return f"Hello, I'm {self.name}"

person = Person("Alice", 30)
print(person)

# With post-init processing
@dataclass
class Rectangle:
    width: float
    height: float
    area: float = field(init=False)

    def __post_init__(self):
        self.area = self.width * self.height

# Frozen (immutable)
@dataclass(frozen=True)
class Point:
    x: int
    y: int

# With default factory
@dataclass
class Team:
    name: str
    members: List[str] = field(default_factory=list)
# Out:
# Person(name='Alice', age=30, email='unknown@example.com')

# %% [markdown]
# Best Code Style

# %%
# Good naming conventions
user_name = "Alice"  # snake_case for variables
MAX_SIZE = 100       # UPPER_CASE for constants

class UserProfile:   # PascalCase for classes
    pass

def calculate_total():  # snake_case for functions
    pass

# Proper spacing
def function(a, b, c):
    result = (a + b) * c
    return result

# Line length (max 79 characters)
# Use line breaks for long expressions
total = (first_value + second_value +
         third_value + fourth_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2878812816.py in <cell line: 0>()
#      16 # Line length (max 79 characters)
#      17 # Use line breaks for long expressions
# ---> 18 total = (first_value + second_value +
#      19          third_value + fourth_value)
#
# NameError: name 'first_value' is not defined

# %% [markdown]
# def calculate_area(width: float, height: float) -> float:
#     """
#     Calculate the area of a rectangle.
#
#     Args:
#         width (float): The width of the rectangle
#         height (float): The height of the rectangle
#
#     Returns:
#         float: The area of the rectangle
#
#     Raises:
#         ValueError: If width or height is negative
#
#     Example:
#         >>> calculate_area(5, 3)
#         15.0
#     """
#     if width < 0 or height < 0:
#         raise ValueError("Dimensions must be positive")
#     return width * height

# %%
# Be specific with exceptions
def divide(a, b):
    if not isinstance(a, (int, float)) or not isinstance(b, (int, float)):
        raise TypeError("Both arguments must be numbers")
    if b == 0:
        raise ValueError("Cannot divide by zero")
    return a / b

# Use context managers for resource management
with open("file.txt") as f:
    content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2134240164.py in <cell line: 0>()
#       8
#       9 # Use context managers for resource management
# ---> 10 with open("file.txt") as f:
#      11     content = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
import unittest

class TestCalculator(unittest.TestCase):
    def test_addition(self):
        self.assertEqual(2 + 2, 4)

    def test_division(self):
        with self.assertRaises(ZeroDivisionError):
            1 / 0

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /root/ (unittest.loader._FailedTest./root/)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import sklearn as sl

data = pd.DataFrame({"name": ['Satish', 'Santosh', 'Mani'], "score": ["69", "78", "89"]}
                    )
print(data)
# Out:
#       name score
# 0   Satish    69
# 1  Santosh    78
# 2     Mani    89

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2
output = inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias
print(output)
# Out:
# 2.3

# %%
inputs = [3,2,1.5]
weights = [[0.2,0.4,0.4], [0.3, 0.4, 0.5], [0.4, 0.5, 0.6]]
bias = [1,3,6]

weights1 = weights[0] #LIST OF WEIGHTS ASSOCIATED WITH 1ST NEURON : W11, W12, W13, W14
weights2 = weights[1] #LIST OF WEIGHTS ASSOCIATED WITH 2ND NEURON : W21, W22, W23, W24
weights3 = weights[2] #LIST OF WEIGHTS ASSOCIATED WITH 3RD NEURON : W31, W32, W33, W34

#output = inputs[0]*weights[0][0] + inputs[1]*weights[1][0] + inputs[2]*weights[2][0] + bias[0]
output = inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + bias[0]
print(output)
# Out:
# 3.0

# %%
inputs = [1.1, 2.2, 3.3]
##LIST OF WEIGHTS
#weights = [[0.2, 0.8, -0.5, 1], [0.5, -0.91, 0.26, -0.5], [-0.26, -0.27, 0.17, 0.87]]
weights = [[2,0,0], [2,2,0], [2,2,2]]
##LIST OF BIASES
#biases = [2, 3, 0.5]
biases = [0,0,1]
# Output of current layer
layer_outputs = []

for neuron_weights, neuron_biases in zip(weights, biases):
    neuron_output = 0
    for n_input, weight in zip(inputs, neuron_weights):
        neuron_output += n_input*weight
         # Add bias
    neuron_output += neuron_biases ## ## W31*X1 + W32*X2 + W33*X3 + W34*X4 + B3
# Put neuron's result to the layer's output list
layer_outputs.append(neuron_output)
print (layer_outputs)
# Out:
# [14.2]

# %%
import numpy as np

#inputs = [1.1, 2.2, 3.3]
#weights = [[2,0,0], [2,2,0], [2,2,2]]
#biases = [2, 3, 0.5]
#output =np.dot(inputs, weights)
#finalOutput = np.dot(output, biases)
#print(finalOutput)

inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0
outputs = np.dot(weights, inputs) + bias
print (outputs)
# Out:
# 4.8
